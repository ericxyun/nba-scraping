# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from itertools import count
from selenium.webdriver.support.ui import WebDriverWait
from time import sleep

RANK = []
TEAM = []
GP = []
W = []
L = []
WIN_PERC = []
MIN = []
PTS = []
FGM = []
FGA = []
FG_PERC = []
THREE_PM = []
THREE_PA = []
THREE_P_PERC = []
FTM = []
FTA = []
FT_PERC = []
OREB = []
DREB = []
REB = []
AST = []
TOV = []
STL = []
BLK = []
BLKA = []
PF = []
PFD = []
PLUS_MINUS = []

column =[RANK, TEAM, GP, W, L, WIN_PERC, MIN, PTS, FGM, FGA, FG_PERC, THREE_PM, THREE_PA, THREE_P_PERC, FTM, FTA, FT_PERC, OREB, DREB, REB, AST, TOV, STL, BLK, BLKA, PF, PFD, PLUS_MINUS]

column_list =["RANK", "TEAM", "GP", "W", "L", "WIN_PERC", "MIN", "PTS", "FGM", "FGA", "FG_PERC", "THREE_PM", "THREE_PA", "THREE_P_PERC", "FTM", "FTA", "FT_PERC", "OREB", "DREB", "REB", "AST", "TOV", "STL", "BLK", "BLKA", "PF", "PFD", "PLUS_MINUS"]

url = 'https://stats.nba.com/teams/traditional/?sort=W_PCT&dir=-1'
browser = webdriver.Safari()
browser.get(url)
table = browser.find_element_by_class_name('nba-stat-table__overflow')
text = table.text.split('\n')

for i, j in enumerate(text, -61):
    if (i > 0 and
        i < 870 and
        i % 29 != 0):
        try:
            column[(i % 29)-1].append(j)
        except:
            continue

browser.quit()

df_T = pd.DataFrame(column)
for i , j in enumerate(column_list):
    df_T.rename({i:j}, inplace=True)
df = df_T.T

df
# Out:
#             RANK                              TEAM            GP  \
# 0              1                   Toronto Raptors            17
# 1              2                   Milwaukee Bucks            16
# 2              3                       LA Clippers            16
# 3              3                 Memphis Grizzlies            16
# 4              3            Portland Trail Blazers            16
# 5              6             Golden State Warriors            18
# 6              6             Oklahoma City Thunder            15
# 7              8                    Indiana Pacers            17
# 8              9                Philadelphia 76ers            19
# 9             10                    Denver Nuggets            17
# 10            10              New Orleans Pelicans            17
# 11            12                   Detroit Pistons            14
# 12            13                Los Angeles Lakers            16
# 13            14                   Houston Rockets            15
# 14            15                    Boston Celtics            17
# 15            15                     Orlando Magic            17
# 16            17                 Charlotte Hornets            16
# 17            17                  Sacramento Kings            16
# 18            17                 San Antonio Spurs            16
# 19            20                         Utah Jazz            17
# 20            21                  Dallas Mavericks            16
# 21            22                     Brooklyn Nets            17
# 22            22            Minnesota Timberwolves            17
# 23            24                        Miami Heat            16
# 24            25                Washington Wizards            16
# 25            26                     Chicago Bulls            17
# 26            26                   New York Knicks            17
# 27            28                      Phoenix Suns            16
# 28            29                     Atlanta Hawks            17
# 29            30               Cleveland Cavaliers            15
#
#                W             L        WIN_PERC             MIN  \
# 0             13             4            .765            48.3
# 1             12             4            .750            48.3
# 2             11             5            .688            48.6
# 3             11             5            .688            48.3
# 4             11             5            .688            48.3
# 5             12             6            .667            48.3
# 6             10             5            .667            48.0
# 7             11             6            .647            48.0
# 8             12             7            .632            49.1
# 9             10             7            .588            48.3
# 10            10             7            .588            48.0
# 11             8             6            .571            49.1
# 12             9             7            .563            48.3
# 13             8             7            .533            48.0
# 14             9             8            .529            48.6
# 15             9             8            .529            48.0
# 16             8             8            .500            48.6
# 17             8             8            .500            48.0
# 18             8             8            .500            48.6
# 19             8             9            .471            48.0
# 20             7             9            .438            48.3
# 21             7            10            .412            48.3
# 22             7            10            .412            48.0
# 23             6            10            .375            48.3
# 24             5            11            .313            48.3
# 25             4            13            .235            48.9
# 26             4            13            .235            48.6
# 27             3            13            .188            48.3
# 28             3            14            .176            48.0
# 29             2            13            .133            48.0
#
#                 PTS             FGM             FGA       ...         \
# 0             116.8            44.1            90.7       ...
# 1             120.1            44.3            91.5       ...
# 2             117.9            41.7            88.3       ...
# 3             103.0            37.1            81.9       ...
# 4             114.9            41.4            90.2       ...
# 5             116.6            43.6            87.9       ...
# 6             110.9            41.1            91.5       ...
# 7             105.7            40.8            85.1       ...
# 8             113.2            39.6            87.3       ...
# 9             110.5            41.6            89.2       ...
# 10            119.5            44.9            92.3       ...
# 11            110.0            40.2            93.4       ...
# 12            116.7            44.8            93.6       ...
# 13            105.3            37.1            85.7       ...
# 14            105.8            39.2            89.9       ...
# 15            107.5            41.2            90.2       ...
# 16            115.0            42.3            92.6       ...
# 17            113.7            43.8            91.4       ...
# 18            108.8            40.4            90.8       ...
# 19            106.0            37.7            82.7       ...
# 20            109.4            39.4            85.8       ...
# 21            109.9            40.1            89.8       ...
# 22            109.6            39.6            90.9       ...
# 23            109.3            39.3            89.1       ...
# 24            110.9            39.8            87.8       ...
# 25            103.1            38.4            87.4       ...
# 26            107.8            39.9            91.2       ...
# 27            102.8            38.1            83.2       ...
# 28            107.4            39.1            89.2       ...
# 29            103.3            38.8            86.4       ...
#
#               DREB             REB             AST             TOV  \
# 0             36.2            46.9            24.9            15.2
# 1             40.9            51.3            26.6            15.7
# 2             37.3            46.8            22.6            14.8
# 3             31.1            38.9            23.3            13.7
# 4             39.9            51.6            20.7            15.0
# 5             35.8            45.7            28.4            14.8
# 6             33.9            47.1            21.3            14.7
# 7             33.5            41.6            23.1            14.5
# 8             38.6            48.8            26.1            16.7
# 9             34.7            46.6            25.9            14.4
# 10            36.1            47.9            27.5            14.8
# 11            35.6            48.5            21.4            14.8
# 12            35.1            46.1            25.1            15.4
# 13            30.5            41.1            20.5            14.4
# 14            36.2            46.4            23.9            13.6
# 15            32.8            42.6            26.2            13.7
# 16            34.8            44.9            24.4            13.0
# 17            34.7            44.6            24.4            15.4
# 18            33.8            45.4            22.9            12.3
# 19            32.8            42.1            23.4            15.6
# 20            35.1            44.7            22.6            16.9
# 21            31.8            44.1            23.6            14.2
# 22            32.8            44.1            23.1            14.3
# 23            35.8            47.6            22.4            16.7
# 24            31.8            41.0            22.6            14.6
# 25            34.0            41.5            21.6            15.5
# 26            32.6            45.2            18.4            15.2
# 27            32.2            39.9            23.8            17.7
# 28            34.4            44.3            24.4            18.5
# 29            31.8            43.7            19.9            15.7
#
#                STL            BLK           BLKA              PF  \
# 0              9.2            5.6            4.8            22.6
# 1              6.8            6.4            5.1            20.8
# 2              5.6            5.6            6.4            24.0
# 3              9.8            5.1            4.7            22.3
# 4              5.9            4.7            6.2            20.8
# 5              7.2            5.9            3.7            22.9
# 6             11.3            5.7            4.7            22.9
# 7              9.2            5.3            6.2            19.8
# 8              6.6            5.6            5.1            23.9
# 9              8.4            4.9            6.1            21.4
# 10             6.9            5.8            5.0            23.0
# 11             6.6            4.0            4.8            24.8
# 12             8.8            6.1            5.9            21.5
# 13             8.4            6.1            4.6            22.7
# 14             7.8            5.2            3.4            21.1
# 15             7.5            6.1            4.8            20.8
# 16             7.0            5.9            6.8            21.3
# 17             8.6            4.5            5.6            22.9
# 18             6.4            4.1            4.6            18.7
# 19             8.4            5.6            4.2            22.7
# 20             7.2            4.9            4.9            21.6
# 21             6.9            4.4            4.9            23.7
# 22             9.5            5.6            5.4            20.2
# 23             6.6            6.6            6.0            23.7
# 24             8.2            6.3            5.0            23.4
# 25             7.6            4.9            7.0            20.4
# 26             7.8            4.8            6.4            23.5
# 27             7.4            3.8            4.9            24.8
# 28             8.5            5.6            5.8            24.2
# 29             7.6            2.7            5.5            21.7
#
#                PFD       PLUS_MINUS
# 0             21.5              8.4
# 1             20.4             11.1
# 2             25.5              5.1
# 3             23.0              3.0
# 4             21.4              6.9
# 5             20.4              6.1
# 6             25.2              5.4
# 7             20.4              4.8
# 8             25.1              0.3
# 9             22.0              6.0
# 10            23.3              2.7
# 11            23.9             -0.1
# 12            21.4              1.3
# 13            20.5             -0.3
# 14            20.2              2.4
# 15            20.1             -2.1
# 16            22.1              4.6
# 17            22.3             -2.6
# 18            22.3             -0.9
# 19            24.5             -2.5
# 20            24.8              0.8
# 21            21.7             -1.4
# 22            22.1             -4.5
# 23            24.2             -1.3
# 24            23.9             -5.9
# 25            18.9            -10.4
# 26            22.2             -6.9
# 27            20.4            -10.7
# 28            24.0            -10.9
# 29            20.5             -8.6
#
# [30 rows x 28 columns]

# %%
# Out:
#   File "<ipython-input-17-64655ddd9c7e>", line 1
#     df.loc[:, df["TEAM"] == LA Clipper]
#                                      ^
# SyntaxError: invalid syntax
